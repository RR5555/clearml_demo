# %% [markdown]
# Clearml Demo
# ---

# %% [markdown]
# # On the server side

# %% [markdown]
# Required:
# * Having installed and set up the clearml-server (cf. [Self-hosted ClearML Server behind a firewall -- Setting up a ClearML Server on a Linux host behind a firewall](https://red.blissfox.xyz/blog/2024/clearml-server/))
# * Running the clearml-server (See Launching & Checking below)
#
# A Python interpreter with `ipykernel` installed.
#
# > To create a venv:
# > ```bash
# > ~/Documents/VENV$ python -m venv ./venv_ipynb
# > ```
# > Requires `python-3.10-venv` or equivalent for used python version:
# > ```bash
# > sudo apt install python3.10-venv
# > ```
#
# > `Ctrl`+`Shift`+`P`: `Python: Select Interpreter`\
# > Then, select kernel for ipynb in VSCode.

# %% [markdown]
# ## Launching clearml-server

# %%
# !docker compose -f /opt/clearml/docker-compose.yml up -d
# Out:
# WARN[0000] The "CLEARML_HOST_IP" variable is not set. Defaulting to a blank string.
# WARN[0000] The "CLEARML_AGENT_GIT_PASS" variable is not set. Defaulting to a blank string.
# WARN[0000] The "CLEARML_AGENT_GIT_USER" variable is not set. Defaulting to a blank string.
# WARN[0000] The "ELASTIC_PASSWORD" variable is not set. Defaulting to a blank string.
# WARN[0000] The "ELASTIC_PASSWORD" variable is not set. Defaulting to a blank string.
# WARN[0000] The "ELASTIC_PASSWORD" variable is not set. Defaulting to a blank string.
# [+] Running 1/0
#  ✔ Network clearml-server_frontend  C...                                   0.1s
#  ⠋ Network clearml-server_backend   Cr...                                  0.0s
# [+] Running 2/2
#  ✔ Network clearml-server_frontend  C...                                   0.1s
#  ✔ Network clearml-server_backend   Cr...                                  0.1s
#  ⠋ Container clearml-mongo          Creating                               0.0s
#  ⠋ Container clearml-redis          Creating                               0.0s
#  ⠋ Container clearml-elastic        Creatin...                             0.0s
#  ⠋ Container clearml-fileserver     Crea...                                0.0s
# [+] Running 6/6
#  ✔ Network clearml-server_frontend  C...                                   0.1s
#  ✔ Network clearml-server_backend   Cr...                                  0.1s
#  ✔ Container clearml-mongo          Created                                0.1s
#  ✔ Container clearml-redis          Created                                0.1s
#  ✔ Container clearml-elastic        Created                                0.1s
#  ✔ Container clearml-fileserver     Crea...                                0.1s
#  ⠋ Container clearml-apiserver      Creat...                               0.0s
# [+] Running 6/7
#  ✔ Network clearml-server_frontend   Created                               0.1s
#  ✔ Network clearml-server_backend    C...                                  0.1s
#  ⠙ Container clearml-mongo           Starting                              0.2s
#  ⠙ Container clearml-redis           Starting                              0.2s
#  ⠙ Container clearml-elastic         Starti...                             0.2s
#  ⠙ Container clearml-fileserver      Sta...                                0.2s
#  ✔ Container clearml-apiserver       Crea...                               0.0s
#  ✔ Container clearml-webserver       Crea...                               0.1s
#  ✔ Container clearml-agent-services  Created                               0.1s
#  ✔ Container async_delete            Created                               0.1s
# [+] Running 6/10
#  ✔ Network clearml-server_frontend   Created                               0.1s
#  ✔ Network clearml-server_backend    C...                                  0.1s
#  ⠹ Container clearml-mongo           Starting                              0.3s
#  ⠹ Container clearml-redis           Starting                              0.3s
#  ⠹ Container clearml-elastic         Starti...                             0.3s
#  ⠹ Container clearml-fileserver      Sta...                                0.3s
#  ✔ Container clearml-apiserver       Crea...                               0.0s
#  ✔ Container clearml-webserver       Crea...                               0.1s
#  ✔ Container clearml-agent-services  Created                               0.1s
#  ✔ Container async_delete            Created                               0.1s
# [+] Running 6/10
#  ✔ Network clearml-server_frontend   Created                               0.1s
#  ✔ Network clearml-server_backend    C...                                  0.1s
#  ⠸ Container clearml-mongo           Starting                              0.4s
#  ⠸ Container clearml-redis           Starting                              0.4s
#  ⠸ Container clearml-elastic         Starti...                             0.4s
#  ⠸ Container clearml-fileserver      Sta...                                0.4s
#  ✔ Container clearml-apiserver       Crea...                               0.0s
#  ✔ Container clearml-webserver       Crea...                               0.1s
#  ✔ Container clearml-agent-services  Created                               0.1s
#  ✔ Container async_delete            Created                               0.1s
# [+] Running 9/10
#  ✔ Network clearml-server_frontend   Created                               0.1s
#  ✔ Network clearml-server_backend    C...                                  0.1s
#  ✔ Container clearml-mongo           Started                               0.5s
#  ✔ Container clearml-redis           Started                               0.5s
#  ⠼ Container clearml-elastic         Starti...                             0.5s
#  ✔ Container clearml-fileserver      Sta...                                0.5s
#  ✔ Container clearml-apiserver       Crea...                               0.0s
#  ✔ Container clearml-webserver       Crea...                               0.1s
#  ✔ Container clearml-agent-services  Created                               0.1s
#  ✔ Container async_delete            Created                               0.1s
# [+] Running 9/10
#  ✔ Network clearml-server_frontend   Created                               0.1s
#  ✔ Network clearml-server_backend    C...                                  0.1s
#  ✔ Container clearml-mongo           Started                               0.5s
#  ✔ Container clearml-redis           Started                               0.5s
#  ✔ Container clearml-elastic         Starte...                             0.5s
#  ✔ Container clearml-fileserver      Sta...                                0.5s
#  ⠙ Container clearml-apiserver       Star...                               0.5s
#  ✔ Container clearml-webserver       Crea...                               0.1s
#  ✔ Container clearml-agent-services  Created                               0.1s
#  ✔ Container async_delete            Created                               0.1s
# [+] Running 9/10
#  ✔ Network clearml-server_frontend   Created                               0.1s
#  ✔ Network clearml-server_backend    C...                                  0.1s
#  ✔ Container clearml-mongo           Started                               0.5s
#  ✔ Container clearml-redis           Started                               0.5s
#  ✔ Container clearml-elastic         Starte...                             0.5s
#  ✔ Container clearml-fileserver      Sta...                                0.5s
#  ⠹ Container clearml-apiserver       Star...                               0.6s
#  ✔ Container clearml-webserver       Crea...                               0.1s
#  ✔ Container clearml-agent-services  Created                               0.1s
#  ✔ Container async_delete            Created                               0.1s
# [+] Running 7/10
#  ✔ Network clearml-server_frontend   Created                               0.1s
#  ✔ Network clearml-server_backend    C...                                  0.1s
#  ✔ Container clearml-mongo           Started                               0.5s
#  ✔ Container clearml-redis           Started                               0.5s
#  ✔ Container clearml-elastic         Starte...                             0.5s
#  ✔ Container clearml-fileserver      Sta...                                0.5s
#  ✔ Container clearml-apiserver       Star...                               0.7s
#  ⠙ Container clearml-webserver       Star...                               0.7s
#  ⠙ Container clearml-agent-services  Starting                              0.7s
#  ⠙ Container async_delete            Starting                              0.7s
# [+] Running 7/10
#  ✔ Network clearml-server_frontend   Created                               0.1s
#  ✔ Network clearml-server_backend    C...                                  0.1s
#  ✔ Container clearml-mongo           Started                               0.5s
#  ✔ Container clearml-redis           Started                               0.5s
#  ✔ Container clearml-elastic         Starte...                             0.5s
#  ✔ Container clearml-fileserver      Sta...                                0.5s
#  ✔ Container clearml-apiserver       Star...                               0.7s
#  ⠹ Container clearml-webserver       Star...                               0.8s
#  ⠹ Container clearml-agent-services  Starting                              0.8s
#  ⠹ Container async_delete            Starting                              0.8s
# [+] Running 7/10
#  ✔ Network clearml-server_frontend   Created                               0.1s
#  ✔ Network clearml-server_backend    C...                                  0.1s
#  ✔ Container clearml-mongo           Started                               0.5s
#  ✔ Container clearml-redis           Started                               0.5s
#  ✔ Container clearml-elastic         Starte...                             0.5s
#  ✔ Container clearml-fileserver      Sta...                                0.5s
#  ✔ Container clearml-apiserver       Star...                               0.7s
#  ⠸ Container clearml-webserver       Star...                               0.9s
#  ⠸ Container clearml-agent-services  Starting                              0.9s
#  ⠸ Container async_delete            Starting                              0.9s
# [+] Running 9/10
#  ✔ Network clearml-server_frontend   Created                               0.1s
#  ✔ Network clearml-server_backend    C...                                  0.1s
#  ✔ Container clearml-mongo           Started                               0.5s
#  ✔ Container clearml-redis           Started                               0.5s
#  ✔ Container clearml-elastic         Starte...                             0.5s
#  ✔ Container clearml-fileserver      Sta...                                0.5s
#  ✔ Container clearml-apiserver       Star...                               0.7s
#  ⠼ Container clearml-webserver       Star...                               1.0s
#  ✔ Container clearml-agent-services  Started                               1.0s
#  ✔ Container async_delete            Started                               1.0s
# [+] Running 10/10
#  ✔ Network clearml-server_frontend   Created                               0.1s
#  ✔ Network clearml-server_backend    C...                                  0.1s
#  ✔ Container clearml-mongo           Started                               0.5s
#  ✔ Container clearml-redis           Started                               0.5s
#  ✔ Container clearml-elastic         Starte...                             0.5s
#  ✔ Container clearml-fileserver      Sta...                                0.5s
#  ✔ Container clearml-apiserver       Star...                               0.7s
#  ✔ Container clearml-webserver       Star...                               1.0s
#  ✔ Container clearml-agent-services  Started                               1.0s
#  ✔ Container async_delete            Started                               1.0s

# %% [markdown]
# ```bash
# ~$ docker compose -f /opt/clearml/docker-compose.yml up -d
# ...
# WARN[0000] The "CLEARML_HOST_IP" variable is not set. Defaulting to a blank string.
# WARN[0000] The "CLEARML_AGENT_GIT_PASS" variable is not set. Defaulting to a blank string.
# WARN[0000] The "CLEARML_AGENT_GIT_USER" variable is not set. Defaulting to a blank string.
# WARN[0000] The "ELASTIC_PASSWORD" variable is not set. Defaulting to a blank string.
# WARN[0000] The "ELASTIC_PASSWORD" variable is not set. Defaulting to a blank string.
# WARN[0000] The "ELASTIC_PASSWORD" variable is not set. Defaulting to a blank string.
# nning 1/0
#  ✔ Network clearml-server_frontend  C...                                   0.1s
#  ⠋ Network clearml-server_backend   Cr...                                  0.0s
# [+] Running 2/2
#  ✔ Network clearml-server_frontend  C...                                   0.1s
#  ✔ Network clearml-server_backend   Cr...                                  0.1s
#  ⠋ Container clearml-mongo          Creating                               0.0s
#  ⠋ Container clearml-redis          Creating                               0.0s
#  ⠋ Container clearml-elastic        Creatin...                             0.0s
#  ⠋ Container clearml-fileserver     Crea...                                0.0s
# [+] Running 6/6
#  ✔ Network clearml-server_frontend  C...                                   0.1s
#  ✔ Network clearml-server_backend   Cr...                                  0.1s
#  ✔ Container clearml-mongo          Created                                0.1s
#  ✔ Container clearml-redis          Created                                0.1s
#  ✔ Container clearml-elastic        Created                                0.1s
#  ✔ Container clearml-fileserver     Crea...                                0.1s
#  ⠋ Container clearml-apiserver      Creat...                               0.0s
# nning 6/7
# ...
#  ✔ Container clearml-apiserver       Star...                               0.7s
#  ✔ Container clearml-webserver       Star...                               1.0s
#  ✔ Container clearml-agent-services  Started                               1.0s
#  ✔ Container async_delete            Started                               1.0s
# ```

# %% [markdown]
# ## Checking clearml-server is running

# %%
# !docker compose ls
# Out:
# NAME                STATUS              CONFIG FILES
# clearml-server      running(7)          /opt/clearml/docker-compose.yml

# %% [markdown]
# ```bash
# ~$ docker compose ls
# NAME                STATUS              CONFIG FILES
# clearml-server      running(7)          /opt/clearml/docker-compose.yml
# ```

# %% [markdown]
# ## Stopping clearml-server

# %%
# !docker compose -p clearml-server down
# Out:
# [+] Running 1/0
#  ⠋ Container clearml-webserver       Stop...                               0.1s
#  ⠋ Container async_delete            Stopping                              0.1s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠙ Container clearml-webserver       Stop...                               0.2s
#  ⠙ Container async_delete            Stopping                              0.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠹ Container clearml-webserver       Stop...                               0.3s
#  ⠹ Container async_delete            Stopping                              0.3s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠸ Container clearml-webserver       Stop...                               0.4s
#  ⠸ Container async_delete            Stopping                              0.4s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠼ Container clearml-webserver       Stop...                               0.5s
#  ⠼ Container async_delete            Stopping                              0.5s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠴ Container clearml-webserver       Stop...                               0.6s
#  ⠴ Container async_delete            Stopping                              0.6s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠦ Container clearml-webserver       Stop...                               0.7s
#  ⠦ Container async_delete            Stopping                              0.7s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠧ Container clearml-webserver       Stop...                               0.8s
#  ⠧ Container async_delete            Stopping                              0.8s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠇ Container clearml-webserver       Stop...                               0.9s
#  ⠇ Container async_delete            Stopping                              0.9s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠏ Container clearml-webserver       Stop...                               1.0s
#  ⠏ Container async_delete            Stopping                              1.0s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠋ Container clearml-webserver       Stop...                               1.1s
#  ⠋ Container async_delete            Stopping                              1.1s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠙ Container clearml-webserver       Stop...                               1.2s
#  ⠙ Container async_delete            Stopping                              1.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠹ Container clearml-webserver       Stop...                               1.3s
#  ⠹ Container async_delete            Stopping                              1.3s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠸ Container clearml-webserver       Stop...                               1.4s
#  ⠸ Container async_delete            Stopping                              1.4s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠼ Container clearml-webserver       Stop...                               1.5s
#  ⠼ Container async_delete            Stopping                              1.5s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠴ Container clearml-webserver       Stop...                               1.6s
#  ⠴ Container async_delete            Stopping                              1.6s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠦ Container clearml-webserver       Stop...                               1.7s
#  ⠦ Container async_delete            Stopping                              1.7s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠧ Container clearml-webserver       Stop...                               1.8s
#  ⠧ Container async_delete            Stopping                              1.8s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠇ Container clearml-webserver       Stop...                               1.9s
#  ⠇ Container async_delete            Stopping                              1.9s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠏ Container clearml-webserver       Stop...                               2.0s
#  ⠏ Container async_delete            Stopping                              2.0s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠋ Container clearml-webserver       Stop...                               2.1s
#  ⠋ Container async_delete            Stopping                              2.1s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠙ Container clearml-webserver       Stop...                               2.2s
#  ⠙ Container async_delete            Stopping                              2.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠹ Container clearml-webserver       Stop...                               2.3s
#  ⠹ Container async_delete            Stopping                              2.3s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠸ Container clearml-webserver       Stop...                               2.4s
#  ⠸ Container async_delete            Stopping                              2.4s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠼ Container clearml-webserver       Stop...                               2.5s
#  ⠼ Container async_delete            Stopping                              2.5s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠴ Container clearml-webserver       Stop...                               2.6s
#  ⠴ Container async_delete            Stopping                              2.6s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠦ Container clearml-webserver       Stop...                               2.7s
#  ⠦ Container async_delete            Stopping                              2.7s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠧ Container clearml-webserver       Stop...                               2.8s
#  ⠧ Container async_delete            Stopping                              2.8s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠇ Container clearml-webserver       Stop...                               2.9s
#  ⠇ Container async_delete            Stopping                              2.9s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠏ Container clearml-webserver       Stop...                               3.0s
#  ⠏ Container async_delete            Stopping                              3.0s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠋ Container clearml-webserver       Stop...                               3.1s
#  ⠋ Container async_delete            Stopping                              3.1s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠙ Container clearml-webserver       Stop...                               3.2s
#  ⠙ Container async_delete            Stopping                              3.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠹ Container clearml-webserver       Stop...                               3.3s
#  ⠹ Container async_delete            Stopping                              3.3s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠸ Container clearml-webserver       Stop...                               3.4s
#  ⠸ Container async_delete            Stopping                              3.4s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠼ Container clearml-webserver       Stop...                               3.5s
#  ⠼ Container async_delete            Stopping                              3.5s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠴ Container clearml-webserver       Stop...                               3.6s
#  ⠴ Container async_delete            Stopping                              3.6s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠦ Container clearml-webserver       Stop...                               3.7s
#  ⠦ Container async_delete            Stopping                              3.7s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠧ Container clearml-webserver       Stop...                               3.8s
#  ⠧ Container async_delete            Stopping                              3.8s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠇ Container clearml-webserver       Stop...                               3.9s
#  ⠇ Container async_delete            Stopping                              3.9s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠏ Container clearml-webserver       Stop...                               4.0s
#  ⠏ Container async_delete            Stopping                              4.0s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠋ Container clearml-webserver       Stop...                               4.1s
#  ⠋ Container async_delete            Stopping                              4.1s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠙ Container clearml-webserver       Stop...                               4.2s
#  ⠙ Container async_delete            Stopping                              4.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠹ Container clearml-webserver       Stop...                               4.3s
#  ⠹ Container async_delete            Stopping                              4.3s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠸ Container clearml-webserver       Stop...                               4.4s
#  ⠸ Container async_delete            Stopping                              4.4s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠼ Container clearml-webserver       Stop...                               4.5s
#  ⠼ Container async_delete            Stopping                              4.5s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠴ Container clearml-webserver       Stop...                               4.6s
#  ⠴ Container async_delete            Stopping                              4.6s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠦ Container clearml-webserver       Stop...                               4.7s
#  ⠦ Container async_delete            Stopping                              4.7s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠧ Container clearml-webserver       Stop...                               4.8s
#  ⠧ Container async_delete            Stopping                              4.8s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠇ Container clearml-webserver       Stop...                               4.9s
#  ⠇ Container async_delete            Stopping                              4.9s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠏ Container clearml-webserver       Stop...                               5.0s
#  ⠏ Container async_delete            Stopping                              5.0s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠋ Container clearml-webserver       Stop...                               5.1s
#  ⠋ Container async_delete            Stopping                              5.1s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠙ Container clearml-webserver       Stop...                               5.2s
#  ⠙ Container async_delete            Stopping                              5.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠹ Container clearml-webserver       Stop...                               5.3s
#  ⠹ Container async_delete            Stopping                              5.3s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠸ Container clearml-webserver       Stop...                               5.4s
#  ⠸ Container async_delete            Stopping                              5.4s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠼ Container clearml-webserver       Stop...                               5.5s
#  ⠼ Container async_delete            Stopping                              5.5s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠴ Container clearml-webserver       Stop...                               5.6s
#  ⠴ Container async_delete            Stopping                              5.6s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠦ Container clearml-webserver       Stop...                               5.7s
#  ⠦ Container async_delete            Stopping                              5.7s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠧ Container clearml-webserver       Stop...                               5.8s
#  ⠧ Container async_delete            Stopping                              5.8s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠇ Container clearml-webserver       Stop...                               5.9s
#  ⠇ Container async_delete            Stopping                              5.9s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠏ Container clearml-webserver       Stop...                               6.0s
#  ⠏ Container async_delete            Stopping                              6.0s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠋ Container clearml-webserver       Stop...                               6.1s
#  ⠋ Container async_delete            Stopping                              6.1s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠙ Container clearml-webserver       Stop...                               6.2s
#  ⠙ Container async_delete            Stopping                              6.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠹ Container clearml-webserver       Stop...                               6.3s
#  ⠹ Container async_delete            Stopping                              6.3s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠸ Container clearml-webserver       Stop...                               6.4s
#  ⠸ Container async_delete            Stopping                              6.4s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠼ Container clearml-webserver       Stop...                               6.5s
#  ⠼ Container async_delete            Stopping                              6.5s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠴ Container clearml-webserver       Stop...                               6.6s
#  ⠴ Container async_delete            Stopping                              6.6s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠦ Container clearml-webserver       Stop...                               6.7s
#  ⠦ Container async_delete            Stopping                              6.7s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠧ Container clearml-webserver       Stop...                               6.8s
#  ⠧ Container async_delete            Stopping                              6.8s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠇ Container clearml-webserver       Stop...                               6.9s
#  ⠇ Container async_delete            Stopping                              6.9s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠏ Container clearml-webserver       Stop...                               7.0s
#  ⠏ Container async_delete            Stopping                              7.0s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠋ Container clearml-webserver       Stop...                               7.1s
#  ⠋ Container async_delete            Stopping                              7.1s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠙ Container clearml-webserver       Stop...                               7.2s
#  ⠙ Container async_delete            Stopping                              7.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠹ Container clearml-webserver       Stop...                               7.3s
#  ⠹ Container async_delete            Stopping                              7.3s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠸ Container clearml-webserver       Stop...                               7.4s
#  ⠸ Container async_delete            Stopping                              7.4s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠼ Container clearml-webserver       Stop...                               7.5s
#  ⠼ Container async_delete            Stopping                              7.5s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠴ Container clearml-webserver       Stop...                               7.6s
#  ⠴ Container async_delete            Stopping                              7.6s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠦ Container clearml-webserver       Stop...                               7.7s
#  ⠦ Container async_delete            Stopping                              7.7s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠧ Container clearml-webserver       Stop...                               7.8s
#  ⠧ Container async_delete            Stopping                              7.8s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠇ Container clearml-webserver       Stop...                               7.9s
#  ⠇ Container async_delete            Stopping                              7.9s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠏ Container clearml-webserver       Stop...                               8.0s
#  ⠏ Container async_delete            Stopping                              8.0s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠋ Container clearml-webserver       Stop...                               8.1s
#  ⠋ Container async_delete            Stopping                              8.1s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠙ Container clearml-webserver       Stop...                               8.2s
#  ⠙ Container async_delete            Stopping                              8.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠹ Container clearml-webserver       Stop...                               8.3s
#  ⠹ Container async_delete            Stopping                              8.3s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠸ Container clearml-webserver       Stop...                               8.4s
#  ⠸ Container async_delete            Stopping                              8.4s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠼ Container clearml-webserver       Stop...                               8.5s
#  ⠼ Container async_delete            Stopping                              8.5s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠴ Container clearml-webserver       Stop...                               8.6s
#  ⠴ Container async_delete            Stopping                              8.6s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠦ Container clearml-webserver       Stop...                               8.7s
#  ⠦ Container async_delete            Stopping                              8.7s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠧ Container clearml-webserver       Stop...                               8.8s
#  ⠧ Container async_delete            Stopping                              8.8s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠇ Container clearml-webserver       Stop...                               8.9s
#  ⠇ Container async_delete            Stopping                              8.9s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠏ Container clearml-webserver       Stop...                               9.0s
#  ⠏ Container async_delete            Stopping                              9.0s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠋ Container clearml-webserver       Stop...                               9.1s
#  ⠋ Container async_delete            Stopping                              9.1s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠙ Container clearml-webserver       Stop...                               9.2s
#  ⠙ Container async_delete            Stopping                              9.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠹ Container clearml-webserver       Stop...                               9.3s
#  ⠹ Container async_delete            Stopping                              9.3s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠸ Container clearml-webserver       Stop...                               9.4s
#  ⠸ Container async_delete            Stopping                              9.4s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠼ Container clearml-webserver       Stop...                               9.5s
#  ⠼ Container async_delete            Stopping                              9.5s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠴ Container clearml-webserver       Stop...                               9.6s
#  ⠴ Container async_delete            Stopping                              9.6s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠦ Container clearml-webserver       Stop...                               9.7s
#  ⠦ Container async_delete            Stopping                              9.7s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠧ Container clearml-webserver       Stop...                               9.8s
#  ⠧ Container async_delete            Stopping                              9.8s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠇ Container clearml-webserver       Stop...                               9.9s
#  ⠇ Container async_delete            Stopping                              9.9s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠏ Container clearml-webserver       Stop...                              10.0s
#  ⠏ Container async_delete            Stopping                             10.0s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 1/3
#  ⠋ Container clearml-webserver       Stop...                              10.1s
#  ⠋ Container async_delete            Stopping                             10.1s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 2/3
#  ⠙ Container clearml-webserver       Stop...                              10.2s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 2/3
#  ⠹ Container clearml-webserver       Stop...                              10.3s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
# [+] Running 3/3
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠋ Container clearml-apiserver       Stop...                               0.0s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠙ Container clearml-apiserver       Stop...                               0.1s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠹ Container clearml-apiserver       Stop...                               0.2s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠸ Container clearml-apiserver       Stop...                               0.3s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠼ Container clearml-apiserver       Stop...                               0.4s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠴ Container clearml-apiserver       Stop...                               0.5s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠦ Container clearml-apiserver       Stop...                               0.6s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠧ Container clearml-apiserver       Stop...                               0.7s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠇ Container clearml-apiserver       Stop...                               0.8s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠏ Container clearml-apiserver       Stop...                               0.9s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠋ Container clearml-apiserver       Stop...                               1.0s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠙ Container clearml-apiserver       Stop...                               1.1s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠹ Container clearml-apiserver       Stop...                               1.2s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠸ Container clearml-apiserver       Stop...                               1.3s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠼ Container clearml-apiserver       Stop...                               1.4s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠴ Container clearml-apiserver       Stop...                               1.5s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠦ Container clearml-apiserver       Stop...                               1.6s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠧ Container clearml-apiserver       Stop...                               1.7s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠇ Container clearml-apiserver       Stop...                               1.8s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠏ Container clearml-apiserver       Stop...                               1.9s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠋ Container clearml-apiserver       Stop...                               2.0s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠙ Container clearml-apiserver       Stop...                               2.1s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠹ Container clearml-apiserver       Stop...                               2.2s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠸ Container clearml-apiserver       Stop...                               2.3s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠼ Container clearml-apiserver       Stop...                               2.4s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠴ Container clearml-apiserver       Stop...                               2.5s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠦ Container clearml-apiserver       Stop...                               2.6s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠧ Container clearml-apiserver       Stop...                               2.7s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠇ Container clearml-apiserver       Stop...                               2.8s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠏ Container clearml-apiserver       Stop...                               2.9s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠋ Container clearml-apiserver       Stop...                               3.0s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠙ Container clearml-apiserver       Stop...                               3.1s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠹ Container clearml-apiserver       Stop...                               3.2s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠸ Container clearml-apiserver       Stop...                               3.3s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠼ Container clearml-apiserver       Stop...                               3.4s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠴ Container clearml-apiserver       Stop...                               3.5s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠦ Container clearml-apiserver       Stop...                               3.6s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠧ Container clearml-apiserver       Stop...                               3.7s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠇ Container clearml-apiserver       Stop...                               3.8s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠏ Container clearml-apiserver       Stop...                               3.9s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠋ Container clearml-apiserver       Stop...                               4.0s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠙ Container clearml-apiserver       Stop...                               4.1s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠹ Container clearml-apiserver       Stop...                               4.2s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠸ Container clearml-apiserver       Stop...                               4.3s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠼ Container clearml-apiserver       Stop...                               4.4s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠴ Container clearml-apiserver       Stop...                               4.5s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠦ Container clearml-apiserver       Stop...                               4.6s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠧ Container clearml-apiserver       Stop...                               4.7s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠇ Container clearml-apiserver       Stop...                               4.8s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠏ Container clearml-apiserver       Stop...                               4.9s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠋ Container clearml-apiserver       Stop...                               5.0s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠙ Container clearml-apiserver       Stop...                               5.1s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠹ Container clearml-apiserver       Stop...                               5.2s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠸ Container clearml-apiserver       Stop...                               5.3s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠼ Container clearml-apiserver       Stop...                               5.4s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠴ Container clearml-apiserver       Stop...                               5.5s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠦ Container clearml-apiserver       Stop...                               5.6s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠧ Container clearml-apiserver       Stop...                               5.7s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠇ Container clearml-apiserver       Stop...                               5.8s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠏ Container clearml-apiserver       Stop...                               5.9s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠋ Container clearml-apiserver       Stop...                               6.0s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ⠙ Container clearml-apiserver       Stop...                               6.1s
# [+] Running 3/4
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
# ...
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ⠧ Container clearml-fileserver      Sto...                                8.8s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
# [+] Running 7/8
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ⠇ Container clearml-fileserver      Sto...                                8.9s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
# [+] Running 7/8
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ⠏ Container clearml-fileserver      Sto...                                9.0s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
# [+] Running 7/8
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ⠋ Container clearml-fileserver      Sto...                                9.1s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
# [+] Running 7/8
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ⠙ Container clearml-fileserver      Sto...                                9.2s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
# [+] Running 7/8
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ⠹ Container clearml-fileserver      Sto...                                9.3s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
# [+] Running 7/8
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ⠸ Container clearml-fileserver      Sto...                                9.4s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
# [+] Running 7/8
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ⠼ Container clearml-fileserver      Sto...                                9.5s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
# [+] Running 7/8
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ⠴ Container clearml-fileserver      Sto...                                9.6s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
# [+] Running 7/8
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ⠦ Container clearml-fileserver      Sto...                                9.7s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
# [+] Running 7/8
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ⠧ Container clearml-fileserver      Sto...                                9.8s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
# [+] Running 7/8
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ⠇ Container clearml-fileserver      Sto...                                9.9s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
# [+] Running 7/8
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ⠏ Container clearml-fileserver      Sto...                               10.0s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
# [+] Running 7/8
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ⠋ Container clearml-fileserver      Sto...                               10.1s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
# [+] Running 7/8
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ⠙ Container clearml-fileserver      Sto...                               10.2s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
# [+] Running 7/8
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ⠹ Container clearml-fileserver      Sto...                               10.3s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
# [+] Running 7/8
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ⠸ Container clearml-fileserver      Sto...                               10.4s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
# [+] Running 8/8
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ✔ Container clearml-fileserver      Rem...                               10.5s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
#  ⠋ Network clearml-server_frontend   Removing                              0.0s
#  ⠋ Network clearml-server_backend    R...                                  0.0s
# [+] Running 8/10
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ✔ Container clearml-fileserver      Rem...                               10.5s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
#  ⠙ Network clearml-server_frontend   Removing                              0.1s
#  ⠙ Network clearml-server_backend    R...                                  0.1s
# [+] Running 9/10
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ✔ Container clearml-fileserver      Rem...                               10.5s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
#  ✔ Network clearml-server_frontend   Removed                               0.2s
#  ⠹ Network clearml-server_backend    R...                                  0.2s
# [+] Running 9/10
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ✔ Container clearml-fileserver      Rem...                               10.5s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
#  ✔ Network clearml-server_frontend   Removed                               0.2s
#  ⠸ Network clearml-server_backend    R...                                  0.3s
# [+] Running 9/10
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ✔ Container clearml-fileserver      Rem...                               10.5s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
#  ✔ Network clearml-server_frontend   Removed                               0.2s
#  ⠼ Network clearml-server_backend    R...                                  0.4s
# [+] Running 10/10
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ✔ Container clearml-fileserver      Rem...                               10.5s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
#  ✔ Network clearml-server_frontend   Removed                               0.2s
#  ✔ Network clearml-server_backend    R...                                  0.5s

# %% [markdown]
# ```bash
# ~$ docker compose -p clearml-server down
# ...
# [+] Running 10/10
#  ✔ Container clearml-webserver       Remo...                              10.4s
#  ✔ Container async_delete            Removed                              10.2s
#  ✔ Container clearml-agent-services  Removed                               0.0s
#  ✔ Container clearml-apiserver       Remo...                              10.4s
#  ✔ Container clearml-mongo           Removed                               0.2s
#  ✔ Container clearml-fileserver      Rem...                               10.5s
#  ✔ Container clearml-redis           Removed                               0.2s
#  ✔ Container clearml-elastic         Remove...                             0.7s
#  ✔ Network clearml-server_frontend   Removed                               0.2s
#  ✔ Network clearml-server_backend    R...                                  0.5s
# ```

# %% [markdown]
# # On the Client side

# %% [markdown]
# Use the 'right' venv for the ipynb kernel (Might need to first `Python: Select Interpreter`, before the venv is proposed as an available kernel).

# %% [markdown]
# **Install the packages for the demo in the venv:**
#
# Either call:
# ```bash
# make install-env
# ```
# Or directly run:

# %%
# %pip install -r requirements.txt
# Out:
# Collecting clearml
#   Downloading clearml-1.16.4-py2.py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 7.0 MB/s eta 0:00:00:00:010:01
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 37.2 MB/s eta 0:00:0000:0100:01
# Collecting pandas
#   Using cached pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
# Collecting joblib
#   Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 10.1 MB/s eta 0:00:0000:010:010m
# Collecting numpy
#   Downloading numpy-2.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 36.6 MB/s eta 0:00:0000:0100:01
# Collecting pathlib2>=2.3.0
#   Using cached pathlib2-2.3.7.post1-py2.py3-none-any.whl (18 kB)
# Collecting pyparsing>=2.0.3
#   Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 KB 1.6 MB/s eta 0:00:0000:01
# Requirement already satisfied: python-dateutil>=2.6.1 in /home/blissfox-server/VENV/venv_jupyter/lib/python3.10/site-packages (from clearml->-r requirements.txt (line 1)) (2.9.0.post0)
# Collecting PyYAML>=3.12
#   Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 KB 10.3 MB/s eta 0:00:0000:01
# Collecting requests>=2.20.0
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 KB 1.3 MB/s eta 0:00:00ta 0:00:01
# Collecting referencing<0.40
#   Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Collecting attrs>=18.0
#   Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 KB 1.0 MB/s eta 0:00:00:00:01
# Collecting urllib3>=1.21.1
#   Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.4/121.4 KB 2.2 MB/s eta 0:00:00a 0:00:01
# Collecting pyjwt<2.9.0,>=2.4.0
#   Using cached PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: six>=1.13.0 in /home/blissfox-server/VENV/venv_jupyter/lib/python3.10/site-packages (from clearml->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: psutil>=3.4.2 in /home/blissfox-server/VENV/venv_jupyter/lib/python3.10/site-packages (from clearml->-r requirements.txt (line 1)) (6.0.0)
# Collecting Pillow>=4.1.1
#   Downloading pillow-10.4.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 10.3 MB/s eta 0:00:0000:010:010m
# Collecting jsonschema>=2.6.0
#   Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 KB 1.5 MB/s eta 0:00:00ta 0:00:01
# Collecting furl>=2.0.0
#   Using cached furl-2.1.3-py2.py3-none-any.whl (20 kB)
# Collecting scipy>=1.6.0
#   Downloading scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 19.8 MB/s eta 0:00:0000:0100:01
# Collecting threadpoolctl>=3.1.0
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Collecting pytz>=2020.1
#   Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.0/508.0 KB 9.8 MB/s eta 0:00:0000:01
# Requirement already satisfied: packaging>=20.0 in /home/blissfox-server/VENV/venv_jupyter/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 6)) (24.1)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.53.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 38.3 MB/s eta 0:00:00:00:0100:01
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.7-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.7 MB/s eta 0:00:00:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.0/322.0 KB 1.5 MB/s eta 0:00:0000:01
# Collecting orderedmultidict>=1.0.1
#   Using cached orderedmultidict-1.0.1-py2.py3-none-any.whl (11 kB)
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (354 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.8/354.8 KB 7.9 MB/s eta 0:00:0000:01
# Collecting jsonschema-specifications>=2023.03.6
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.3/167.3 KB 3.1 MB/s eta 0:00:0000:01
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.8-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 KB 1.2 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: pytz, urllib3, tzdata, threadpoolctl, rpds-py, PyYAML, pyparsing, pyjwt, Pillow, pathlib2, orderedmultidict, numpy, kiwisolver, joblib, idna, fonttools, cycler, charset-normalizer, certifi, attrs, scipy, requests, referencing, pandas, furl, contourpy, scikit-learn, matplotlib, jsonschema-specifications, jsonschema, clearml
# Successfully installed Pillow-10.4.0 PyYAML-6.0.2 attrs-24.2.0 certifi-2024.8.30 charset-normalizer-3.3.2 clearml-1.16.4 contourpy-1.3.0 cycler-0.12.1 fonttools-4.53.1 furl-2.1.3 idna-3.8 joblib-1.4.2 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 kiwisolver-1.4.7 matplotlib-3.9.2 numpy-2.1.1 orderedmultidict-1.0.1 pandas-2.2.2 pathlib2-2.3.7.post1 pyjwt-2.8.0 pyparsing-3.1.4 pytz-2024.2 referencing-0.35.1 requests-2.32.3 rpds-py-0.20.0 scikit-learn-1.5.2 scipy-1.14.1 threadpoolctl-3.5.0 tzdata-2024.1 urllib3-2.2.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# > WARNING:\
# > Using:
# > ```python
# > !the_cmd
# > ```
# > Resulted in weird behaviours: agent present to closing down and could not take on any task from the queue
# > Instead using:
# > ```python
# > %%bash
# > the_cmd
# > ```
# > Resulted in the correct behaviours

# %% [markdown]
# ## Launch an exp. from a public repo.
#
# We will:
# * Launch an agent/worker on a brand new queue: it will wait for a load (created a container? Or container only under load?)
# * Launch a task from the CLI calling a script from a public GitHub repo
# * Stop the agent

# %% [markdown]
# First, let's check if any agent is running:

# %%
# %%bash
# clearml-agent list
# Out:
# workers:
# - company:
#     id: d1bd92a3b039400cbafc60a7a5b1e52b
#     name: clearml
#   id: clearml-agent-bengio:gpu1
#   ip: 172.25.1.1
#   key: worker_d1bd92a3b039400cbafc60a7a5b1e52b_0f358a174884f2c34ef7def624d3e1a0_clearml-agent-bengio:gpu1
#   last_activity_time: '2024-09-17T12:03:34.651007+00:00'
#   last_report_time: '2024-09-17T12:03:34.651007+00:00'
#   queues:
#   - id: 6b55ab8e3be4482eb53acfed3e4037a5
#     name: gpu_dithering
#     num_tasks: 0
#   register_time: '2024-09-17T11:55:23.175388+00:00'
#   register_timeout: 600
#   system_tags: []
#   tags: []
#   user:
#     id: 0f358a174884f2c34ef7def624d3e1a0
#     name: RR5555

# %% [markdown]
# **To launch an agent:**\
# *(with name `clearml-agent-bengio`, id `clearml-agent-bengio:gpu0`, on gpu 0 with queue `gpu_dithering`)*
#
# Either call:
# ```bash
# make launch-agent
# ```
# Or directly call:

# %%
# %%bash
# CLEARML_WORKER_NAME=clearml-agent-bengio CLEARML_WORKER_ID=clearml-agent-bengio:gpu0 clearml-agent daemon --detached --queue gpu_dithering --create-queue --gpus 0
# Out:
# Current configuration (clearml_agent v1.9.1, location: /home/blissfox-server/clearml.conf):
# ----------------------
# agent.worker_id = clearml-agent-bengio:gpu0
# agent.worker_name = clearml-agent-bengio
# agent.force_git_ssh_protocol = false
# agent.python_binary = /usr/bin/python3.10
# agent.package_manager.type = pip
# agent.package_manager.pip_version.0 = <20.2 ; python_version < '3.10'
# agent.package_manager.pip_version.1 = <22.3 ; python_version >\= '3.10' and python_version <\= '3.11'
# agent.package_manager.pip_version.2 = >\=23,<24.3 ; python_version >\= '3.12'
# agent.package_manager.system_site_packages = false
# agent.package_manager.force_upgrade = false
# agent.package_manager.conda_channels.0 = pytorch
# agent.package_manager.conda_channels.1 = conda-forge
# agent.package_manager.conda_channels.2 = nvidia
# agent.package_manager.conda_channels.3 = defaults
# agent.package_manager.priority_optional_packages.0 = pygobject
# agent.package_manager.torch_nightly = false
# agent.package_manager.poetry_files_from_repo_working_dir = false
# agent.venvs_dir = /home/blissfox-server/.clearml/venvs-builds
# agent.venvs_cache.max_entries = 10
# agent.venvs_cache.free_space_threshold_gb = 2.0
# agent.venvs_cache.path = ~/.clearml/venvs-cache
# agent.vcs_cache.enabled = true
# agent.vcs_cache.path = /home/blissfox-server/.clearml/vcs-cache
# agent.venv_update.enabled = false
# agent.pip_download_cache.enabled = true
# agent.pip_download_cache.path = /home/blissfox-server/.clearml/pip-download-cache
# agent.translate_ssh = true
# agent.reload_config = false
# agent.docker_pip_cache = /home/blissfox-server/.clearml/pip-cache
# agent.docker_apt_cache = /home/blissfox-server/.clearml/apt-cache
# agent.docker_force_pull = false
# agent.default_docker.image = nvidia/cuda:11.0.3-cudnn8-runtime-ubuntu20.04
# agent.default_docker.match_rules.0.image = python:3.6-bullseye
# agent.default_docker.match_rules.0.arguments = --ipc\=host
# agent.default_docker.match_rules.0.match.script.binary = python3.6$
# agent.default_docker.match_rules.1.image = python:3.7-bullseye
# agent.default_docker.match_rules.1.arguments = --ipc\=host
# agent.default_docker.match_rules.1.match.script.binary = python3.7$
# agent.default_docker.match_rules.2.image = python:3.8-bullseye
# agent.default_docker.match_rules.2.arguments = --ipc\=host
# agent.default_docker.match_rules.2.match.script.binary = python3.8$
# agent.default_docker.match_rules.3.image = python:3.9-bullseye
# agent.default_docker.match_rules.3.arguments = --ipc\=host
# agent.default_docker.match_rules.3.match.script.binary = python3.9$
# agent.default_docker.match_rules.4.image = python:3.10-bullseye
# agent.default_docker.match_rules.4.arguments = --ipc\=host
# agent.default_docker.match_rules.4.match.script.binary = python3.10$
# agent.default_docker.match_rules.5.image = python:3.11-bullseye
# agent.default_docker.match_rules.5.arguments = --ipc\=host
# agent.default_docker.match_rules.5.match.script.binary = python3.11$
# agent.default_docker.match_rules.6.image = python:3.12-bullseye
# agent.default_docker.match_rules.6.arguments = --ipc\=host
# agent.default_docker.match_rules.6.match.script.binary = python3.12$
# agent.enable_task_env = false
# agent.sanitize_config_printout = ****
# agent.hide_docker_command_env_vars.enabled = true
# agent.hide_docker_command_env_vars.parse_embedded_urls = true
# agent.abort_callback_max_timeout = 1800
# agent.docker_internal_mounts.sdk_cache = /clearml_agent_cache
# agent.docker_internal_mounts.apt_cache = /var/cache/apt/archives
# agent.docker_internal_mounts.ssh_folder = ~/.ssh
# agent.docker_internal_mounts.ssh_ro_folder = /.ssh
# agent.docker_internal_mounts.pip_cache = /root/.cache/pip
# agent.docker_internal_mounts.poetry_cache = /root/.cache/pypoetry
# agent.docker_internal_mounts.vcs_cache = /root/.clearml/vcs-cache
# agent.docker_internal_mounts.venvs_cache = /root/.clearml/venvs-cache
# agent.docker_internal_mounts.venv_build = ~/.clearml/venvs-builds
# agent.docker_internal_mounts.pip_download = /root/.clearml/pip-download-cache
# agent.apply_environment = true
# agent.apply_files = true
# agent.custom_build_script =
# agent.disable_task_docker_override = false
# agent.git_user = RR5555
# agent.git_pass = ****
# agent.default_python = 3.10
# agent.cuda_version = 122
# agent.cudnn_version = 0
# sdk.storage.cache.default_base_dir = ~/.clearml/cache
# sdk.storage.cache.size.min_free_bytes = 10GB
# sdk.storage.direct_access.0.url = file://*
# sdk.metrics.file_history_size = 100
# sdk.metrics.matplotlib_untitled_history_size = 100
# sdk.metrics.images.format = JPEG
# sdk.metrics.images.quality = 87
# sdk.metrics.images.subsampling = 0
# sdk.metrics.tensorboard_single_series_per_graph = false
# sdk.network.metrics.file_upload_threads = 4
# sdk.network.metrics.file_upload_starvation_warning_sec = 120
# sdk.network.iteration.max_retries_on_server_error = 5
# sdk.network.iteration.retry_backoff_factor_sec = 10
# sdk.network.file_upload_retries = 3
# sdk.aws.s3.key =
# sdk.aws.s3.secret = ****
# sdk.aws.s3.region =
# sdk.aws.s3.use_credentials_chain = false
# sdk.aws.boto3.pool_connections = 512
# sdk.aws.boto3.max_multipart_concurrency = 16
# sdk.aws.boto3.multipart_threshold = 8388608
# sdk.aws.boto3.multipart_chunksize = 8388608
# sdk.log.null_log_propagate = false
# sdk.log.task_log_buffer_capacity = 66
# sdk.log.disable_urllib3_info = true
# sdk.development.task_reuse_time_window_in_hours = 72.0
# sdk.development.vcs_repo_detect_async = true
# sdk.development.store_uncommitted_code_diff = true
# sdk.development.support_stopping = true
# sdk.development.default_output_uri =
# sdk.development.force_analyze_entire_repo = false
# sdk.development.suppress_update_message = false
# sdk.development.detect_with_pip_freeze = false
# sdk.development.worker.report_period_sec = 2
# sdk.development.worker.ping_period_sec = 30
# sdk.development.worker.log_stdout = true
# sdk.development.worker.report_global_mem_used = false
# sdk.development.worker.report_event_flush_threshold = 100
# sdk.development.worker.console_cr_flush_period = 10
# sdk.apply_environment = false
# sdk.apply_files = false
# api.version = 1.5
# api.verify_certificate = true
# api.default_version = 1.5
# api.http.max_req_size = 15728640
# api.http.retries.total = 240
# api.http.retries.connect = 240
# api.http.retries.read = 240
# api.http.retries.redirect = 240
# api.http.retries.status = 240
# api.http.retries.backoff_factor = 1.0
# api.http.retries.backoff_max = 120.0
# api.http.wait_on_maintenance_forever = true
# api.http.pool_maxsize = 512
# api.http.pool_connections = 512
# api.auth.token_expiration_threshold_sec = ****
# api.api_server = https://api.clearml.blissfox.xyz
# api.web_server = https://app.clearml.blissfox.xyz
# api.files_server = https://files.clearml.blissfox.xyz
# api.credentials.access_key = EUAQEJNSXKQU1UN76PMC
# api.credentials.secret_key = ****
# api.host = https://api.clearml.blissfox.xyz
#
# Worker "clearml-agent-bengio:gpu0" - Listening to queues:
# +----------------------------------+---------------+-------+
# | id                               | name          | tags  |
# +----------------------------------+---------------+-------+
# | 6b55ab8e3be4482eb53acfed3e4037a5 | gpu_dithering |       |
# +----------------------------------+---------------+-------+
#
# Running CLEARML-AGENT daemon in background mode, writing stdout/stderr to /tmp/.clearml_agent_daemon_outmsvbjz7b.txt

# %%
# Out:
# a.log                integrated_test.py          requirements.txt
# dataset.py           Makefile                    reuse_artifact.py
# demo.ipynb           pipeline_from_decorator.py  step1_dataset_artifact.py
# img/                 pipeline_from_functions.py  step2_data_processing.py
# __init__.py          pipeline_from_tasks.py      step3_train_model.py
# integrated_test2.py  __pycache__/                storage.py
# integrated_test3.py  README.md                   test.py

# %% [markdown]
# > WARNING:\
# > The shell processes launched from the ipynb will stop when the ipynb will be closed!

# %% [markdown]
# <details>
# <summary>Output</summary>
#
# ```bash
# Current configuration (clearml_agent v1.9.1, location: /home/blissfox-server/clearml.conf):
# ----------------------
# agent.worker_id = clearml-agent-bengio:gpu0
# agent.worker_name = clearml-agent-bengio
# agent.force_git_ssh_protocol = false
# agent.python_binary = /usr/bin/python3.10
# agent.package_manager.type = pip
# agent.package_manager.pip_version.0 = <20.2 ; python_version < '3.10'
# agent.package_manager.pip_version.1 = <22.3 ; python_version >\= '3.10' and python_version <\= '3.11'
# agent.package_manager.pip_version.2 = >\=23,<24.3 ; python_version >\= '3.12'
# agent.package_manager.system_site_packages = false
# agent.package_manager.force_upgrade = false
# agent.package_manager.conda_channels.0 = pytorch
# agent.package_manager.conda_channels.1 = conda-forge
# agent.package_manager.conda_channels.2 = nvidia
# agent.package_manager.conda_channels.3 = defaults
# agent.package_manager.priority_optional_packages.0 = pygobject
# agent.package_manager.torch_nightly = false
# agent.package_manager.poetry_files_from_repo_working_dir = false
# agent.venvs_dir = /home/blissfox-server/.clearml/venvs-builds
# agent.venvs_cache.max_entries = 10
# agent.venvs_cache.free_space_threshold_gb = 2.0
# agent.venvs_cache.path = ~/.clearml/venvs-cache
# agent.vcs_cache.enabled = true
# agent.vcs_cache.path = /home/blissfox-server/.clearml/vcs-cache
# ...
# | 6b55ab8e3be4482eb53acfed3e4037a5 | gpu_dithering |       |
# +----------------------------------+---------------+-------+
#
# Running CLEARML-AGENT daemon in background mode, writing stdout/stderr to /tmp/.clearml_agent_daemon_out47ajuksj.txt
# ```
#
# </details>

# %% [markdown]
# <details>
# <summary>About the cmd & arguments</summary>
#
# From [ClearML Agent CLI](https://clear.ml/docs/latest/docs/clearml_agent/clearml_agent_ref/):
# |||
# |:---|:---|
# |`daemon`|command to spin up an agent on any machine|
# |`--create-queue`|If the queue name provided with `--queue` does not exist in the server, create it on-the-fly and use it.|
# |`--detached`|Run agent in the background. The `clearml-agent` command returns immediately.|
# |`--gpus`|If running in Docker mode (see the `--docker` option), specify the active GPUs for the Docker containers to use. These are the same GPUs set in the `NVIDIA_VISIBLE_DEVICES` environment variable. For example:<ul><li>`--gpus 0`</li><li>`--gpu 0,1,2`</li><li>`--gpus all`</li></ul>|
# |`--queue`|Specify the queues which the worker is listening to. The values can be any combination of:<ul><li>One or more queue IDs</li><li>One or more queue names</li><li>`default` indicating the default queue</li></ul>
# </details>

# %% [markdown]
# <details>
# <summary>On the GUI:</summary>
#
# * Before:\
#     ![](./img/Workers_null.png)
# * After:\
#     ![](./img/Workers_bengio0_0.png)\
#     ![](./img/Workers_bengio0_1.png)
#
# </details>

# %% [markdown]
# Let's check out again the agent available from the CLI:

# %%
# %%bash
# clearml-agent list
# Out:
# workers:
# - company:
#     id: d1bd92a3b039400cbafc60a7a5b1e52b
#     name: clearml
#   id: clearml-agent-bengio:gpu0
#   ip: 172.25.1.1
#   key: worker_d1bd92a3b039400cbafc60a7a5b1e52b_0f358a174884f2c34ef7def624d3e1a0_clearml-agent-bengio:gpu0
#   last_activity_time: '2024-09-17T12:11:30.313969+00:00'
#   last_report_time: '2024-09-17T12:11:30.313969+00:00'
#   queues:
#   - id: 6b55ab8e3be4482eb53acfed3e4037a5
#     name: gpu_dithering
#     num_tasks: 0
#   register_time: '2024-09-17T12:07:22.702228+00:00'
#   register_timeout: 600
#   system_tags: []
#   tags: []
#   user:
#     id: 0f358a174884f2c34ef7def624d3e1a0
#     name: RR5555

# %% [markdown]
# <details>
# <summary>Output</summary>
#
# ```bash
# workers:
# - company:
#     id: d1bd92a3b039400cbafc60a7a5b1e52b
#     name: clearml
#   id: clearml-agent-bengio:gpu0
#   ip: 172.25.1.1
#   key: worker_d1bd92a3b039400cbafc60a7a5b1e52b_0f358a174884f2c34ef7def624d3e1a0_clearml-agent-bengio:gpu0
#   last_activity_time: '2024-09-16T11:46:44.589928+00:00'
#   queues:
#   - id: 6b55ab8e3be4482eb53acfed3e4037a5
#     name: gpu_dithering
#     num_tasks: 0
#   register_time: '2024-09-16T11:46:44.589928+00:00'
#   register_timeout: 600
#   system_tags: []
#   tags: []
#   user:
#     id: 0f358a174884f2c34ef7def624d3e1a0
#     name: RR5555
# ```
# </details>

# %%
# %%bash
# docker ps
# Out:
# CONTAINER ID   IMAGE          COMMAND                  CREATED        STATUS        PORTS     NAMES
# 5df405395f17   493e8cccec38   "bash -c ' tail -f /…"   3 months ago   Up 25 hours             clearml-test-integrated-exp_container-1

# %%
# %%bash
# clearml-task --project Demo --name clearml_test --script test.py --repo https://github.com/RR5555/clearml_demo.git --branch main --queue gpu_dithering --docker rr5555/dith:cuda12.0-agent
# Out:
# ClearML launch - launch any codebase on remote machine running clearml-agent
# Creating new task
# Repository Detected
# {
#   "repository": "https://github.com/RR5555/clearml_demo.git",
#   "branch": "main",
#   "working_dir": ".",
#   "entry_point": "test.py"
# }
# Base docker image: {'image': 'rr5555/dith:cuda12.0-agent', 'args': None, 'bash_script': None}
# New task created id=9a5fe9c6566f4696889c7dfa51c897c4
# Task id=9a5fe9c6566f4696889c7dfa51c897c4 sent for execution on queue gpu_dithering
# Execution log at: https://app.clearml.blissfox.xyz/projects/ce6d125a264149bc89e8e62fb1dd0d7a/experiments/9a5fe9c6566f4696889c7dfa51c897c4/output/log

# %%
# %%bash
# clearml-task list
# Out:
# ClearML launch - launch any codebase on remote machine running clearml-agent
# usage: clearml-task [-h] [--version] [--project PROJECT] [--name NAME]
#                     [--tags [TAGS ...]] [--repo REPO] [--branch BRANCH]
#                     [--commit COMMIT] [--folder FOLDER] [--script SCRIPT]
#                     [--binary BINARY] [--module MODULE] [--cwd CWD]
#                     [--args [ARGS ...]] [--queue QUEUE]
#                     [--requirements REQUIREMENTS] [--packages [PACKAGES ...]]
#                     [--docker DOCKER] [--docker_args DOCKER_ARGS]
#                     [--docker_bash_setup_script DOCKER_BASH_SETUP_SCRIPT]
#                     [--output-uri OUTPUT_URI] [--task-type TASK_TYPE]
#                     [--skip-task-init] [--base-task-id BASE_TASK_ID]
#                     [--import-offline-session IMPORT_OFFLINE_SESSION]
# clearml-task: error: unrecognized arguments: list
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'clearml-task list\n')
#
# File ~/VENV/venv_jupyter/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/VENV/venv_jupyter/lib/python3.10/site-packages/IPython/core/magics/script.py:155, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     153 else:
#     154     line = script
# --> 155 return self.shebang(line, cell)
#
# File ~/VENV/venv_jupyter/lib/python3.10/site-packages/IPython/core/magics/script.py:315, in ScriptMagics.shebang(self, line, cell)
#     310 if args.raise_error and p.returncode != 0:
#     311     # If we get here and p.returncode is still None, we must have
#     312     # killed it but not yet seen its return code. We don't wait for it,
#     313     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     314     rc = p.returncode or -9
# --> 315     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'clearml-task list\n'' returned non-zero exit status 2.

# %% [markdown]
# **Stop the agent:**

# %%
# %%bash
# clearml-agent daemon --stop clearml-agent-bengio:gpu0
# Out:
# Terminating clearml-agent worker_id=clearml-agent-bengio:gpu1 pid=11676

# %%
# %%bash
# clearml-agent list
# Out:
# workers: []

# %% [markdown]
# ## Launch an exp. from a private repo.
#
# We will:
# * Launch an agent/worker on a brand new queue: it will wait for a load (created a container? Or container only under load?)
# * Launch a task from the CLI calling a script from a public GitHub repo
# * Stop the agent

# %%
# !clearml-task --project Demo --name clearml_test --script clearml/test.py --repo https://github.com/RR5555/Classification_dither.git --branch main --queue gpu_dithering --docker rr5555/dith:cuda12.0-agent

# %% [markdown]
# ```bash
#
# make exp-from-private-repo
# make stop-agent
# make launch-agents
# make pipeline-from-functions
# make pipeline-from-decorator
#
# make create-tasks-for-pipeline
# make pipeline-from-tasks
#
# make stop-agents
# ```

# %% [markdown]
# <details>
# <summary></summary>
#
# </details>
